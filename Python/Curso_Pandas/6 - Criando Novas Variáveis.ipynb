# %% [markdown]
# # Relatório de Análise VI

# %% [markdown]
# ## Criando novas variáveis

# %%
#Importando a biblioteca
import pandas as pd

# %%
#Leitura da Database e armazenamento em objeto
dados = pd.read_csv("Dados/aluguel_Residencial.csv", sep=";")
dados.head(15)
# Out:
#            Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0   Apartamento           Leblon        2      0       0    70   3000.0
# 1   Apartamento          Ipanema        4      2       2   210  28000.0
# 2   Apartamento         Flamengo        3      0       0   115   2700.0
# 3   Apartamento    Bento Ribeiro        2      1       0    53    900.0
# 4   Apartamento           Leblon        4      3       1   178  15000.0
# 5   Apartamento  Barra da Tijuca        2      1       1    94   2200.0
# 6   Apartamento         Cachambi        2      1       0    70   1300.0
# 7   Apartamento  Todos os Santos        3      0       0    70   1000.0
# 8   Apartamento      Vila Isabel        3      1       0    80   1800.0
# 9   Apartamento           Tijuca        1      0       0    42   1600.0
# 10  Apartamento  Barra da Tijuca        4      4       4   290  15000.0
# 11  Apartamento       Copacabana        3      0       0   103   6000.0
# 12  Apartamento           Centro        0      0       0    32    700.0
# 13  Apartamento  Barra da Tijuca        3      2       1   117   4500.0
# 14  Apartamento          Taquara        2      1       0    60   1200.0
#
#     Condominio     IPTU
# 0        760.0      0.0
# 1       3020.0   9247.0
# 2        728.0    223.0
# 3        510.0      0.0
# 4       3000.0      0.0
# 5       1379.0    252.0
# 6        550.0      0.0
# 7        340.0     15.0
# 8        600.0     72.0
# 9        550.0     20.0
# 10      5000.0  15000.0
# 11       780.0    240.0
# 12       358.0     21.0
# 13      1000.0    624.0
# 14       505.0     77.0

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados.head(10)
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0  Apartamento           Leblon        2      0       0    70   3000.0
# 1  Apartamento          Ipanema        4      2       2   210  28000.0
# 2  Apartamento         Flamengo        3      0       0   115   2700.0
# 3  Apartamento    Bento Ribeiro        2      1       0    53    900.0
# 4  Apartamento           Leblon        4      3       1   178  15000.0
# 5  Apartamento  Barra da Tijuca        2      1       1    94   2200.0
# 6  Apartamento         Cachambi        2      1       0    70   1300.0
# 7  Apartamento  Todos os Santos        3      0       0    70   1000.0
# 8  Apartamento      Vila Isabel        3      1       0    80   1800.0
# 9  Apartamento           Tijuca        1      0       0    42   1600.0
#
#    Condominio    IPTU  Valor Bruto
# 0       760.0     0.0       3760.0
# 1      3020.0  9247.0      40267.0
# 2       728.0   223.0       3651.0
# 3       510.0     0.0       1410.0
# 4      3000.0     0.0      18000.0
# 5      1379.0   252.0       3831.0
# 6       550.0     0.0       1850.0
# 7       340.0    15.0       1355.0
# 8       600.0    72.0       2472.0
# 9       550.0    20.0       2170.0

# %%
dados['Valor m2'] = dados['Valor'] / dados['Area']
dados['Valor m2'] = dados['Valor m2'].round(2)
dados.head(10)
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0  Apartamento           Leblon        2      0       0    70   3000.0
# 1  Apartamento          Ipanema        4      2       2   210  28000.0
# 2  Apartamento         Flamengo        3      0       0   115   2700.0
# 3  Apartamento    Bento Ribeiro        2      1       0    53    900.0
# 4  Apartamento           Leblon        4      3       1   178  15000.0
# 5  Apartamento  Barra da Tijuca        2      1       1    94   2200.0
# 6  Apartamento         Cachambi        2      1       0    70   1300.0
# 7  Apartamento  Todos os Santos        3      0       0    70   1000.0
# 8  Apartamento      Vila Isabel        3      1       0    80   1800.0
# 9  Apartamento           Tijuca        1      0       0    42   1600.0
#
#    Condominio    IPTU  Valor Bruto  Valor m2
# 0       760.0     0.0       3760.0     42.86
# 1      3020.0  9247.0      40267.0    133.33
# 2       728.0   223.0       3651.0     23.48
# 3       510.0     0.0       1410.0     16.98
# 4      3000.0     0.0      18000.0     84.27
# 5      1379.0   252.0       3831.0     23.40
# 6       550.0     0.0       1850.0     18.57
# 7       340.0    15.0       1355.0     14.29
# 8       600.0    72.0       2472.0     22.50
# 9       550.0    20.0       2170.0     38.10

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto'] / dados['Area']).round(2)
dados.head(10)
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0  Apartamento           Leblon        2      0       0    70   3000.0
# 1  Apartamento          Ipanema        4      2       2   210  28000.0
# 2  Apartamento         Flamengo        3      0       0   115   2700.0
# 3  Apartamento    Bento Ribeiro        2      1       0    53    900.0
# 4  Apartamento           Leblon        4      3       1   178  15000.0
# 5  Apartamento  Barra da Tijuca        2      1       1    94   2200.0
# 6  Apartamento         Cachambi        2      1       0    70   1300.0
# 7  Apartamento  Todos os Santos        3      0       0    70   1000.0
# 8  Apartamento      Vila Isabel        3      1       0    80   1800.0
# 9  Apartamento           Tijuca        1      0       0    42   1600.0
#
#    Condominio    IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# 0       760.0     0.0       3760.0     42.86           53.71
# 1      3020.0  9247.0      40267.0    133.33          191.75
# 2       728.0   223.0       3651.0     23.48           31.75
# 3       510.0     0.0       1410.0     16.98           26.60
# 4      3000.0     0.0      18000.0     84.27          101.12
# 5      1379.0   252.0       3831.0     23.40           40.76
# 6       550.0     0.0       1850.0     18.57           26.43
# 7       340.0    15.0       1355.0     14.29           19.36
# 8       600.0    72.0       2472.0     22.50           30.90
# 9       550.0    20.0       2170.0     38.10           51.67

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']
dados['Tipo Agregado'] = dados['Tipo'].apply( lambda x: 'Casa' if x in casa else 'Apartamento')
dados.head(10)
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0  Apartamento           Leblon        2      0       0    70   3000.0
# 1  Apartamento          Ipanema        4      2       2   210  28000.0
# 2  Apartamento         Flamengo        3      0       0   115   2700.0
# 3  Apartamento    Bento Ribeiro        2      1       0    53    900.0
# 4  Apartamento           Leblon        4      3       1   178  15000.0
# 5  Apartamento  Barra da Tijuca        2      1       1    94   2200.0
# 6  Apartamento         Cachambi        2      1       0    70   1300.0
# 7  Apartamento  Todos os Santos        3      0       0    70   1000.0
# 8  Apartamento      Vila Isabel        3      1       0    80   1800.0
# 9  Apartamento           Tijuca        1      0       0    42   1600.0
#
#    Condominio    IPTU  Valor Bruto  Valor m2  Valor Bruto m2 Tipo Agregado
# 0       760.0     0.0       3760.0     42.86           53.71   Apartamento
# 1      3020.0  9247.0      40267.0    133.33          191.75   Apartamento
# 2       728.0   223.0       3651.0     23.48           31.75   Apartamento
# 3       510.0     0.0       1410.0     16.98           26.60   Apartamento
# 4      3000.0     0.0      18000.0     84.27          101.12   Apartamento
# 5      1379.0   252.0       3831.0     23.40           40.76   Apartamento
# 6       550.0     0.0       1850.0     18.57           26.43   Apartamento
# 7       340.0    15.0       1355.0     14.29           19.36   Apartamento
# 8       600.0    72.0       2472.0     22.50           30.90   Apartamento
# 9       550.0    20.0       2170.0     38.10           51.67   Apartamento

# %% [markdown]
# ### Excluindo Variáveis

# %%
dados_aux = pd.DataFrame(dados[["Tipo Agregado", "Valor m2", "Valor Bruto", "Valor Bruto m2"]])
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0   Apartamento     42.86       3760.0           53.71
# 1   Apartamento    133.33      40267.0          191.75
# 2   Apartamento     23.48       3651.0           31.75
# 3   Apartamento     16.98       1410.0           26.60
# 4   Apartamento     84.27      18000.0          101.12

# %%
# Opção 1
del dados_aux["Valor Bruto"]
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto m2
# 0   Apartamento     42.86           53.71
# 1   Apartamento    133.33          191.75
# 2   Apartamento     23.48           31.75
# 3   Apartamento     16.98           26.60
# 4   Apartamento     84.27          101.12

# %%
# Opção 2
dados_aux.pop('Valor Bruto m2')
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2
# 0   Apartamento     42.86
# 1   Apartamento    133.33
# 2   Apartamento     23.48
# 3   Apartamento     16.98
# 4   Apartamento     84.27

# %%
# Opção 3 - Usada na base real
dados.drop(["Valor Bruto", "Valor Bruto m2"], axis = 1, inplace = True)
dados.head()
# Out:
#           Tipo         Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0  Apartamento         Leblon        2      0       0    70   3000.0
# 1  Apartamento        Ipanema        4      2       2   210  28000.0
# 2  Apartamento       Flamengo        3      0       0   115   2700.0
# 3  Apartamento  Bento Ribeiro        2      1       0    53    900.0
# 4  Apartamento         Leblon        4      3       1   178  15000.0
#
#    Condominio    IPTU  Valor m2 Tipo Agregado
# 0       760.0     0.0     42.86   Apartamento
# 1      3020.0  9247.0    133.33   Apartamento
# 2       728.0   223.0     23.48   Apartamento
# 3       510.0     0.0     16.98   Apartamento
# 4      3000.0     0.0     84.27   Apartamento

# %%
# Exportando planilha com os novos Dados
dados.to_csv("Dados/aluguel_Residencial.csv", sep=";", index = False)
